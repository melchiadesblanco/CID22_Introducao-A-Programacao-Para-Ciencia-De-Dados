# %% [markdown]
# # Limpeza de Dados - Exercícios
#
# Resolva os exercícios propostos abaixo. Os exercícios usam um dataset de reclamações registradas por cidadãos. O detaset foi derivado de dados do [Portal de Dados Abertos da Prefeitura de Curitiba](https://www.curitiba.pr.gov.br/DADOSABERTOS/).

# %% [markdown]
# ## Leitura e análise inicial dos dados
#
# Inicie um DataFrame a partir do arquivo `2017-02-01_156_-_Base_de_Dados_sample.csv`. Exiba algumas linhas e informações sobre os tipos identificados automaticamente pelo Pandas.
#
# **Dica:** Caso o arquivo não seja separado por vírgulas, o Pandas não conseguirá reconhecer os campos adequadamente. Você precisará fornecer o parâmetro `sep=';'` para indicar o separador correto (neste caso, o `;`).
#
# **Dica:** Aplicativos modernos tendem a armazenar arquivos no formato UTF-8, mas é comum encontrar arquivos codificados em outros formatos. Caso você tenha problemas para ler o arquivo, utilize o parâmetro `encoding='latin-1'` para selecionar o encoding correto (*latin-1* neste exemplo).

# %%
# Resposta:

import pandas as pd

df_bds = pd.read_csv("../data/2017-02-01_156_-_Base_de_Dados_sample.csv", sep=';', encoding='latin-1',  header='infer')
df_bds = df_bds.set_index('SOLICITACAO')

# %% [markdown]
# Visualize algumas linhas de dados:

# %%
# Resposta:
df_bds.sample(n=10)
# Out:
#                     TIPO                               ORGAO        DATA  \
# SOLICITACAO
# 6724522         SUGESTÃO  INSTITUTO DAS CIDADES INTELIGENTES  04/01/2017
# 6739511      SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  15/01/2017
# 6711824      SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  15/12/2016
# 6757894      SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  27/01/2017
# 6716555      SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  22/12/2016
# 6719275      SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  28/12/2016
# 6690269      SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  28/11/2016
# 6757624      SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  27/01/2017
# 6721614      SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  02/01/2017
# 6720999      SOLICITAÇÃO             FUNDAÇÃO DE AÇÃO SOCIAL  31/12/2016
#
#               HORARIO                                    ASSUNTO  \
# SOLICITACAO
# 6724522      18:54:08                                     ÔNIBUS
# 6739511      09:53:42                         ILUMINAÇÃO PÚBLICA
# 6711824      21:29:21                         ILUMINAÇÃO PÚBLICA
# 6757894      13:20:33                         ILUMINAÇÃO PÚBLICA
# 6716555      17:16:02                       SINALIZAÇÃO VERTICAL
# 6719275      10:37:42           ABORDAGEM SOCIAL DE RUA - ADULTO
# 6690269      10:06:35                                     COLETA
# 6757624      11:15:48                                     PRAÇAS
# 6721614      14:56:03                         ILUMINAÇÃO PÚBLICA
# 6720999      19:37:35  ATENDIMENTO SOCIAL EM DOMICÍLIO - CRIANÇA
#
#                                                    SUBDIVISAO  \
# SOLICITACAO
# 6724522                                  SUGESTÃO DE MELHORIA
# 6739511                              MANUTENÇÃO DE LUMINÁRIAS
# 6711824                              MANUTENÇÃO DE LUMINÁRIAS
# 6757894                              MANUTENÇÃO DE LUMINÁRIAS
# 6716555      PROIBIÇÃO DE TRÁFEGO/ESTACIONAMENTO DE CAMINHÕES
# 6719275                                DORMINDO/CAÍDAS NA RUA
# 6690269                ENTULHOS DIVERSOS (PEQUENA QUANTIDADE)
# 6757624                              MANUTENÇÃO DE ILUMINAÇÃO
# 6721614                              MANUTENÇÃO DE LUMINÁRIAS
# 6720999         COMPORTAMENTO - FUGA DE INSTITUIÇÃO DE ABRIGO
#
#                                                      DESCRICAO  \
# SOLICITACAO
# 6724522                          ÔNIBUS - SUGESTÃO DE MELHORIA
# 6739511          ILUMINAÇÃO PÚBLICA - MANUTENÇÃO DE LUMINÁRIAS
# 6711824          ILUMINAÇÃO PÚBLICA - MANUTENÇÃO DE LUMINÁRIAS
# 6757894          ILUMINAÇÃO PÚBLICA - MANUTENÇÃO DE LUMINÁRIAS
# 6716555      SINALIZAÇÃO VERTICAL - PROIBIÇÃO DE TRÁFEGO/ES...
# 6719275      ABORDAGEM SOCIAL DE RUA - ADULTO - DORMINDO/CA...
# 6690269        COLETA - ENTULHOS DIVERSOS (PEQUENA QUANTIDADE)
# 6757624                      PRAÇAS - MANUTENÇÃO DE ILUMINAÇÃO
# 6721614          ILUMINAÇÃO PÚBLICA - MANUTENÇÃO DE LUMINÁRIAS
# 6720999      ATENDIMENTO SOCIAL EM DOMICÍLIO - CRIANÇA - CO...
#
#                               LOGRADOURO_ASS         BAIRRO_ASS  \
# SOLICITACAO
# 6724522      PROFESSOR SEBASTIAO PARANA, 232        VILA IZABEL
# 6739511                   ENETTE DUBARD, 229          TATUQUARA
# 6711824                     JULIO PERNETA, 0             MERCES
# 6757894                       DAS NAÇÕES, 75     ALTO DA RUA XV
# 6716555            FRANCISCO JOSE MARTIN, 69            UBERABA
# 6719275                          IGUAÇÚ, 400           REBOUCAS
# 6690269                      ROCHA POMBO, 59             JUVEVE
# 6757624                  CIRO DE CASTRO, 142  CIDADE INDUSTRIAL
# 6721614                   PEDRO PILATO, 1650             UMBARA
# 6720999                     VITAL BRASIL, 96             PORTAO
#
#                              REGIONAL_ASS MEIO_RESPOSTA  \
# SOLICITACAO
# 6724522           Unidade Regional Portao      TELEFONE
# 6739511        Unidade Regional Tatuquara         EMAIL
# 6711824           Unidade Regional Matriz         EMAIL
# 6757894           Unidade Regional Matriz         EMAIL
# 6716555           Unidade Regional Cajuru         EMAIL
# 6719275           Unidade Regional Matriz        NENHUM
# 6690269           Unidade Regional Matriz         EMAIL
# 6757624              Unidade Regional CIC         EMAIL
# 6721614      Unidade Regional Bairro Novo        NENHUM
# 6720999           Unidade Regional Portao        NENHUM
#
#                                                     OBSERVACAO SEXO  \
# SOLICITACAO
# 6724522                NÃO SOUBE INFORMAR PONTO DE REFERÊNCIA.    M
# 6739511      INFORMA O CÓDIGO DE MANUTENÇÃO DA LUMINÁRIA: F...    M
# 6711824      LOCALIZAM-SE POR TODA A EXTENSÃO DA QUADRA DA ...    M
# 6757894       INFORMA O CÓDIGO DAS LUMINÁRIAS: AADT , CU7-AC4.    M
# 6716555      NÃO SOUBE INFORMAR O COMPLEMENTO DO BAIRRO E O...    F
# 6719275      NO PONTO DE TÁXI ESQUINA COM AV. MARECHAL FLOR...    F
# 6690269                                                    NaN    F
# 6757624      TRANSVERSAL 1: RUA EDUARDO LUIZ PIANA / TRANSV...    M
# 6721614      TRANSVERSAL INFORMADA: NICOLA PELANDA. EM TODA...    F
# 6720999                                                    NaN    F
#
#                 BAIRRO_CIDADAO              REGIONAL_CIDADAO   DATA_NASC  \
# SOLICITACAO
# 6724522            VILA IZABEL       Unidade Regional Portao  16/07/1950
# 6739511              TATUQUARA    Unidade Regional Tatuquara  18/10/1969
# 6711824                 MERCES       Unidade Regional Matriz  13/04/1952
# 6757894         ALTO DA RUA XV       Unidade Regional Matriz  08/10/1957
# 6716555                UBERABA       Unidade Regional Cajuru  25/12/1970
# 6719275             AGUA VERDE       Unidade Regional Portao  13/04/1965
# 6690269                 JUVEVE       Unidade Regional Matriz  22/07/1983
# 6757624      CIDADE INDUSTRIAL          Unidade Regional CIC  13/07/1987
# 6721614                 UMBARA  Unidade Regional Bairro Novo  30/12/1962
# 6720999                 PORTAO       Unidade Regional Portao         NaN
#
#             TIPO_CIDADAO                              ORGAO_RESP  \
# SOLICITACAO
# 6724522          CIDADÃO                 URBANIZAÇÃO DE CURITIBA
# 6739511          CIDADÃO  SECRETARIA MUNICIPAL DE OBRAS PÚBLICAS
# 6711824          CIDADÃO  SECRETARIA MUNICIPAL DE OBRAS PÚBLICAS
# 6757894          CIDADÃO  SECRETARIA MUNICIPAL DE OBRAS PÚBLICAS
# 6716555          CIDADÃO        SECRETARIA MUNICIPAL DE TRÂNSITO
# 6719275          CIDADÃO                 FUNDAÇÃO DE AÇÃO SOCIAL
# 6690269          CIDADÃO   SECRETARIA MUNICIPAL DO MEIO AMBIENTE
# 6757624          CIDADÃO  SECRETARIA MUNICIPAL DE OBRAS PÚBLICAS
# 6721614          CIDADÃO  SECRETARIA MUNICIPAL DE OBRAS PÚBLICAS
# 6720999          CIDADÃO                 FUNDAÇÃO DE AÇÃO SOCIAL
#
#                                                 RESPOSTA_FINAL
# SOLICITACAO
# 6724522      Agradecemos a sua colaboração para manter o si...
# 6739511                                   SOLICITACAO ATENDIDA
# 6711824                                   SOLICITACAO ATENDIDA
# 6757894                                   SOLICITACAO ATENDIDA
# 6716555      Informamos que a proibição de tráfego de camin...
# 6719275      Abordagem realizada. Pessoa foi encaminhada pa...
# 6690269      O contrato de Coleta de Vegetais, caliças e en...
# 6757624                                   SOLICITACAO ATENDIDA
# 6721614                                   SOLICITACAO ATENDIDA
# 6720999      22 - SOLICITAÇÃO ABERTA PELO SETOR DE TRIAGEM ...

# %% [markdown]
# Use o método `info` para exibir as colunas e os tipos identificados.

# %%
# Resposta:

# %% [markdown]
# Estamos interessados apenas nos seguintes campos: 'DATA', 'HORARIO', 'SUBDIVISAO', 'BAIRRO_ASS', 'SEXO', 'DATA_NASC', 'RESPOSTA_FINAL'
#
# Crie (ou substitua) um DataFrame contendo apenas os campos acima.

# %%
# Resposta:

# %% [markdown]
# ## Localizando e tratando valores inválidos

# %% [markdown]
# Exiba todas as linhas com valores em branco (*NaN*).

# %%
# Resposta:

# %% [markdown]
# Exclua todas as linhas que contenham algum valor nulo (*NaN*). Verifique se todas as linhas com valores em branco foram excluídas corretamente.

# %%
# Resposta:

# %% [markdown]
# Faça com que todos os nomes de bairros fiquem em letras minúsculas.

# %%
# Resposta:

# %% [markdown]
# ## Conversão de tipos, criação de coluna e escrita em CSV

# %% [markdown]
# Exiba os tipos das colunas do DataFrame.

# %%
# Resposta:

# %% [markdown]
# - Converta os campos de data para o formato DateTime.
# - Crie uma nova coluna chamada HORA, contendo apenas o componete hora do horário da reclamação (dica: use os comandos str.split e str.get)
# - Converta a coluna HORA para Inteiro

# %%
# Resposta:

# %% [markdown]
# Crie uma coluna chamada `IDADE` contendo a diferença entre o ano da reclamação e o ano de nascimento da pessoa.
#
# **Dica:** Para extrair o ano de uma coluna do tipo data, use a propriedade `dt.year`. Por exemplo: `df['DATA'].dt.year`.

# %%
# Resposta:

# %% [markdown]
# Verifique se as colunas foram corretamente convertidas para os tipos corretos.

# %%
# Resposta:

# %% [markdown]
# Identifique outliers na coluna `IDADE`. Remova do DataFrame todas as reclamações de pessoas com idades muito baixas.

# %%
# Resposta:

# %% [markdown]
# Salve o DataFrame em um arquivo CSV chamado `../data/2017-02-01_156_-_Base_de_Dados_sample-limpo.csv`. Use o parâmetro `index=False` para não incluir o índice no aquivo gerado.

# %%
# Resposta:
