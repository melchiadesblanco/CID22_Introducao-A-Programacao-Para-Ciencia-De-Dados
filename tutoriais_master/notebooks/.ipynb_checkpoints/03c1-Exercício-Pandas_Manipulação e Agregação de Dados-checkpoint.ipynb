# %% [markdown]
# # Manipulação e Agregação de Dados - Exercícios
#
# Resolva os exercícios propostos abaixo. Os exercícios usam um dataset de reclamações registradas por cidadãos. O detaset foi derivado de dados do [Portal de Dados Abertos da Prefeitura de Curitiba](https://www.curitiba.pr.gov.br/DADOSABERTOS/).

# %% [markdown]
# ## Leitura e análise inicial dos dados
#
# Inicie um DataFrame a partir do arquivo `2017-02-01_156_-_Base_de_Dados_sample.csv`.
#
# **Dica:** Caso o arquivo não seja separado por vírgulas, o Pandas não conseguirá reconhecer os campos adequadamente. Você precisará fornecer o parâmetro `sep=';'` para indicar o separador correto (neste caso, o `;`).
#
# **Dica:** Aplicativos modernos tendem a armazenar arquivos no formato UTF-8, mas é comum encontrar arquivos codificados em outros formatos. Caso você tenha problemas para ler o arquivo, utilize o parâmetro `encoding='latin-1'` para selecionar o encoding correto (*latin-1* neste exemplo).

# %%
# Resposta:
import pandas as pd

df_bds = pd.read_csv("../data/2017-02-01_156_-_Base_de_Dados_sample.csv", sep=';', encoding='latin-1',  header='infer')

# %% [markdown]
# Visualize algumas linhas de dados:

# %%
# Resposta:
df_bds.head(10)
# Out:
#    SOLICITACAO         TIPO                               ORGAO        DATA  \
# 0      6669771  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  09/11/2016
# 1      6718351  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  27/12/2016
# 2      6702371  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  07/12/2016
# 3      6718692  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  27/12/2016
# 4      6704503  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  09/12/2016
# 5      6672832  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  12/11/2016
# 6      6712943  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  17/12/2016
# 7      6733811   INFORMAÇÃO       SECRETARIA MUNICIPAL DA SAÚDE  11/01/2017
# 8      6710218   INFORMAÇÃO       SECRETARIA MUNICIPAL DA SAÚDE  14/12/2016
# 9      6701219  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES  06/12/2016
#
#     HORARIO                            ASSUNTO  \
# 0  21:02:44   ABORDAGEM SOCIAL DE RUA - ADULTO
# 1  00:40:04   ABORDAGEM SOCIAL DE RUA - ADULTO
# 2  14:09:42  ABORDAGEM SOCIAL DE RUA - CRIANÇA
# 3  13:28:27   ABORDAGEM SOCIAL DE RUA - ADULTO
# 4  01:28:16   ABORDAGEM SOCIAL DE RUA - ADULTO
# 5  02:29:24   ABORDAGEM SOCIAL DE RUA - ADULTO
# 6  16:06:04                           TRÂNSITO
# 7  12:11:12                         CRM-AF/SMS
# 8  10:19:29                         CRM-AF/SMS
# 9  19:01:01   ABORDAGEM SOCIAL DE RUA - ADULTO
#
#                              SUBDIVISAO  \
# 0  PESSOAS/FAMÍLIAS EM DESABRIGO NA RUA
# 1                  PERDIDA/DESORIENTADA
# 2                 ALCOOLIZADAS/DROGADAS
# 3  PESSOAS/FAMÍLIAS EM DESABRIGO NA RUA
# 4                DORMINDO/CAÍDAS NA RUA
# 5                DORMINDO/CAÍDAS NA RUA
# 6  VEÍCULO ESTACIONADO - GUIA REBAIXADA
# 7     RECURSOS MATERIAIS - MEDICAMENTOS
# 8     RECURSOS MATERIAIS - MEDICAMENTOS
# 9                DORMINDO/CAÍDAS NA RUA
#
#                                            DESCRICAO  \
# 0  ABORDAGEM SOCIAL DE RUA - ADULTO - PESSOAS/FAM...
# 1  ABORDAGEM SOCIAL DE RUA - ADULTO - PERDIDA/DES...
# 2  ABORDAGEM SOCIAL DE RUA - CRIANÇA - ALCOOLIZAD...
# 3  ABORDAGEM SOCIAL DE RUA - ADULTO - PESSOAS/FAM...
# 4  ABORDAGEM SOCIAL DE RUA - ADULTO - DORMINDO/CA...
# 5  ABORDAGEM SOCIAL DE RUA - ADULTO - DORMINDO/CA...
# 6    TRÂNSITO - VEÍCULO ESTACIONADO - GUIA REBAIXADA
# 7     CRM-AF/SMS - RECURSOS MATERIAIS - MEDICAMENTOS
# 8     CRM-AF/SMS - RECURSOS MATERIAIS - MEDICAMENTOS
# 9  ABORDAGEM SOCIAL DE RUA - ADULTO - DORMINDO/CA...
#
#              LOGRADOURO_ASS     BAIRRO_ASS             REGIONAL_ASS  \
# 0        ANDRE DE BARROS, 0         CENTRO  Unidade Regional Matriz
# 1             NILO CAIRO, 0         CENTRO  Unidade Regional Matriz
# 2   VISCONDE DE NACAR, 1210         CENTRO  Unidade Regional Matriz
# 3       MARECHAL DEODORO, 0         CENTRO  Unidade Regional Matriz
# 4       MARECHAL DEODORO, 0         CENTRO  Unidade Regional Matriz
# 5         XV DE NOVEMBRO, 0         CENTRO  Unidade Regional Matriz
# 6         CRUZ MACHADO, 396         CENTRO  Unidade Regional Matriz
# 7           JAIME REIS, 331  SAO FRANCISCO  Unidade Regional Matriz
# 8           JAIME REIS, 331  SAO FRANCISCO  Unidade Regional Matriz
# 9  BARAO DO RIO BRANCO, 720         CENTRO  Unidade Regional Matriz
#
#   MEIO_RESPOSTA                                         OBSERVACAO SEXO  \
# 0        NENHUM               NÃO SOUBE INFORMAR NUMERAÇÃO PREDIAL    M
# 1        NENHUM  NÃO SOUBE INFORMAR NUMERAÇÃO PREDIAL, RELATA E...    M
# 2        NENHUM                                                NaN    F
# 3        NENHUM                                                NaN    M
# 4        NENHUM              NÃO SOUBE INFORMAR NUMERAÇÃO PREDIAL.    M
# 5        NENHUM                    NÃO INFORMOU NUMERAÇÃO PREDIAL.    M
# 6      TELEFONE                                                NaN    M
# 7        NENHUM                                                NaN    F
# 8        NENHUM                                                NaN    F
# 9        NENHUM  HOMEM USA CAMISA PRETA CALÇA JEANS E TÊNIS BRA...    M
#
#   BAIRRO_CIDADAO REGIONAL_CIDADAO   DATA_NASC TIPO_CIDADAO  \
# 0            NaN              NaN         NaN      CIDADÃO
# 1            NaN              NaN         NaN      CIDADÃO
# 2            NaN              NaN         NaN      CIDADÃO
# 3            NaN              NaN         NaN      CIDADÃO
# 4            NaN              NaN  04/06/1997      CIDADÃO
# 5            NaN              NaN  29/12/1971      CIDADÃO
# 6            NaN              NaN         NaN      CIDADÃO
# 7            NaN              NaN  04/08/1957      CIDADÃO
# 8            NaN              NaN  18/08/1938      CIDADÃO
# 9            NaN              NaN  13/02/1980      CIDADÃO
#
#                          ORGAO_RESP  \
# 0           FUNDAÇÃO DE AÇÃO SOCIAL
# 1           FUNDAÇÃO DE AÇÃO SOCIAL
# 2           FUNDAÇÃO DE AÇÃO SOCIAL
# 3           FUNDAÇÃO DE AÇÃO SOCIAL
# 4           FUNDAÇÃO DE AÇÃO SOCIAL
# 5           FUNDAÇÃO DE AÇÃO SOCIAL
# 6  SECRETARIA MUNICIPAL DE TRÂNSITO
# 7     SECRETARIA MUNICIPAL DA SAÚDE
# 8     SECRETARIA MUNICIPAL DA SAÚDE
# 9           FUNDAÇÃO DE AÇÃO SOCIAL
#
#                                       RESPOSTA_FINAL
# 0  Abordagem realizada. Pessoa foi orientada quan...
# 1  EM ABORDAGEM REALIZADA, NÃO FOI ENCONTRADA A P...
# 2  - EM ABORDAGEM REALIZADA, NÃO FOI ENCONTRADA A...
# 3  A pessoa da solicitação já foi abordada nesta ...
# 4  A pessoa da solicitação já faz parte da rede d...
# 5  A pessoa da solicitação já faz parte da rede d...
# 6  Informamos que o atendimento aos pedidos para ...
# 7  Alendronato de sódio 70 mg e Carbonato de cálc...
# 8  ALENDRONATO DE SÓDIO 70 MG  E CARBONATO DE CÁL...
# 9  EM ABORDAGEM REALIZADA, NÃO FOI ENCONTRADA A P...

# %% [markdown]
# Use o método `df.describe(include="all")` para exibir informações sobre as colunas.

# %%
# Resposta:
df_bds.describe(include="all")
# Out:
#          SOLICITACAO         TIPO                               ORGAO  \
# count   7.013000e+03         7013                                7013
# unique           NaN            7                                   5
# top              NaN  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# freq             NaN         5812                                6649
# mean    6.702377e+06          NaN                                 NaN
# std     2.668504e+04          NaN                                 NaN
# min     6.659367e+06          NaN                                 NaN
# 25%     6.680119e+06          NaN                                 NaN
# 50%     6.700369e+06          NaN                                 NaN
# 75%     6.722191e+06          NaN                                 NaN
# max     6.763349e+06          NaN                                 NaN
#
#               DATA   HORARIO ASSUNTO                SUBDIVISAO  \
# count         7013      7013    7013                      7013
# unique          92      6438     148                       388
# top     05/12/2016  11:52:23  COLETA  MANUTENÇÃO DE LUMINÁRIAS
# freq           163         4    1633                       969
# mean           NaN       NaN     NaN                       NaN
# std            NaN       NaN     NaN                       NaN
# min            NaN       NaN     NaN                       NaN
# 25%            NaN       NaN     NaN                       NaN
# 50%            NaN       NaN     NaN                       NaN
# 75%            NaN       NaN     NaN                       NaN
# max            NaN       NaN     NaN                       NaN
#
#                                             DESCRICAO  \
# count                                            7013
# unique                                            482
# top     ILUMINAÇÃO PÚBLICA - MANUTENÇÃO DE LUMINÁRIAS
# freq                                              969
# mean                                              NaN
# std                                               NaN
# min                                               NaN
# 25%                                               NaN
# 50%                                               NaN
# 75%                                               NaN
# max                                               NaN
#
#                          LOGRADOURO_ASS BAIRRO_ASS             REGIONAL_ASS  \
# count                              7013       7013                     7011
# unique                             5612         75                       10
# top     PRESIDENTE AFFONSO CAMARGO, 330     CENTRO  Unidade Regional Matriz
# freq                                 39        436                     1572
# mean                                NaN        NaN                      NaN
# std                                 NaN        NaN                      NaN
# min                                 NaN        NaN                      NaN
# 25%                                 NaN        NaN                      NaN
# 50%                                 NaN        NaN                      NaN
# 75%                                 NaN        NaN                      NaN
# max                                 NaN        NaN                      NaN
#
#        MEIO_RESPOSTA                             OBSERVACAO  SEXO  \
# count           7013                                   3786  7013
# unique             4                                   2585     2
# top            EMAIL  NÃO SOUBE INFORMAR NUMERAÇÃO PREDIAL.     F
# freq            3750                                     88  3613
# mean             NaN                                    NaN   NaN
# std              NaN                                    NaN   NaN
# min              NaN                                    NaN   NaN
# 25%              NaN                                    NaN   NaN
# 50%              NaN                                    NaN   NaN
# 75%              NaN                                    NaN   NaN
# max              NaN                                    NaN   NaN
#
#            BAIRRO_CIDADAO            REGIONAL_CIDADAO   DATA_NASC  \
# count                6897                        6757        6889
# unique                172                          10        5398
# top     CIDADE INDUSTRIAL  Unidade Regional Boa Vista  22/06/1962
# freq                  483                        1130          73
# mean                  NaN                         NaN         NaN
# std                   NaN                         NaN         NaN
# min                   NaN                         NaN         NaN
# 25%                   NaN                         NaN         NaN
# 50%                   NaN                         NaN         NaN
# 75%                   NaN                         NaN         NaN
# max                   NaN                         NaN         NaN
#
#        TIPO_CIDADAO                             ORGAO_RESP  \
# count          7013                                   7013
# unique            1                                     23
# top         CIDADÃO  SECRETARIA MUNICIPAL DO MEIO AMBIENTE
# freq           7013                                   2121
# mean            NaN                                    NaN
# std             NaN                                    NaN
# min             NaN                                    NaN
# 25%             NaN                                    NaN
# 50%             NaN                                    NaN
# 75%             NaN                                    NaN
# max             NaN                                    NaN
#
#                                            RESPOSTA_FINAL
# count                                                7010
# unique                                               3154
# top     O contrato de Coleta de Vegetais, caliças e en...
# freq                                                 1334
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# Crie um novo DataFrame chamado `df_elogios` contendo apenas as linhas cujos valores na culuna `TIPO` são iguais a 'ELOGIO'. Este DataFrame deve ter as colunas TIPO, ASSUNTO, e BAIRRO_CIDADAO.

# %%
# Resposta:
df_elogios = df_bds[df_bds['TIPO'] == 'ELOGIO']
df_elogios = df_elogios[['TIPO', 'ASSUNTO', 'BAIRRO_CIDADAO']]
df_elogios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 124 to 7001
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   TIPO            99 non-null     object
#  1   ASSUNTO         99 non-null     object
#  2   BAIRRO_CIDADAO  99 non-null     object
# dtypes: object(3)
# memory usage: 3.1+ KB

# %% [markdown]
# Quais são os 5 bairros com mais elogios? Agrupe pelo `BAIRRO_CIDADAO` e ordene o resultado para responder.

# %%
# Resposta:
df_elogios_top5 = df_elogios.groupby(['BAIRRO_CIDADAO']).count()
df_elogios_top5 = df_elogios_top5.sort_values(by=['TIPO'], ascending=False).head()
df_elogios_top5['TIPO']
# Out:
# BAIRRO_CIDADAO
# SITIO CERCADO        12
# CIDADE INDUSTRIAL    12
# CAJURU               11
# BOQUEIRAO             6
# BAIRRO ALTO           5
# Name: TIPO, dtype: int64

# %% [markdown]
# Crie dois novos DataFrames, um contendo a as linhas de reclamações de pessoas do sexo masculino e outra do sexo feminino. Use estes DataFrames para responder:
#
# Qual é a proporção de reclamações entre homens e mulhores? (total de reclamações de homens dividido pelo total de reclamações de mulheres)

# %%
# Resposta:

df_reclamacoes_m = df_bds[(df_bds['TIPO'] == 'RECLAMAÇÃO') & (df_bds['SEXO'] == 'M')]
df_reclamacoes_f = df_bds[(df_bds['TIPO'] == 'RECLAMAÇÃO') & (df_bds['SEXO'] == 'F')]

proporcao_reclamacao_mf = df_reclamacoes_m['SOLICITACAO'].count() / df_reclamacoes_f['SOLICITACAO'].count()
#total_linhas_mf = df_reclamacoes_m['SOLICITACAO'].count() + df_reclamacoes_f['SOLICITACAO'].count()
print(proporcao_reclamacao_mf)
# Out:
# 0.5081081081081081

# %% [markdown]
# Concatene os dois DataFrames criados acima para criar um DataFrame chamado `df_todos`. Verifique se este DataFrame tem o mesmo núimero de linhas do DataFrame lido do CSV.

# %%
# Resposta:
df_todos = pd.concat([df_reclamacoes_m, df_reclamacoes_f])

#size counts NaNs while count does not

if df_bds['SOLICITACAO'].count() == df_todos['SOLICITACAO'].count():
    print('Sim, possuem o mesmo numero de linhas!')
else:
    print('Não possuem o mesmo numero de linhas\ndf_bds: {}\ndf_todos: {}'.format(df_bds['SOLICITACAO'].count() ,df_todos['SOLICITACAO'].count()))
# Out:
# Não possuem o mesmo numero de linhas
# df_bds: 7013
# df_todos: 837

# %% [markdown]
# Crie um novo DataFrame chamado `df_sexo` contendo a contagem de reclamações para cada sexo. A coluna com a contagem deve se chamar `contagem`.

# %%
# Resposta:

####
# Conforme orientação do professor (forum), para que esta parte do exericio nao fique igual a anterior estarei assumindo que
# o problema solicita a contagem de 'solicitações' (registros) ao invés de reclamações (TIPO=RECLAMACAO)
####

df_sexo = df_bds.groupby(['SEXO'])['SEXO'].size().reset_index(name = 'CONTAGEM')

df_sexo
# Out:
#   SEXO  CONTAGEM
# 0    F      3613
# 1    M      3400

# %% [markdown]
# Crie um novo DataFrame chamado `df_sexo_tipo` contendo a contagem de reclamações para cada sexo e tipo. A coluna com a contagem deve se chamar `total`.

# %%
# Resposta:

df_sexo_tipo = df_bds.groupby(['SEXO', 'TIPO']).size().reset_index(name = 'TOTAL')

df_sexo_tipo
# Out:
#    SEXO         TIPO  TOTAL
# 0     F     DENÚNCIA     31
# 1     F       ELOGIO     65
# 2     F   INFORMAÇÃO     25
# 3     F   RECADASTRO     79
# 4     F   RECLAMAÇÃO    555
# 5     F  SOLICITAÇÃO   2851
# 6     F     SUGESTÃO      7
# 7     M     DENÚNCIA     13
# 8     M       ELOGIO     34
# 9     M   INFORMAÇÃO     11
# 10    M   RECADASTRO     91
# 11    M   RECLAMAÇÃO    282
# 12    M  SOLICITAÇÃO   2961
# 13    M     SUGESTÃO      8

# %% [markdown]
# Faça uma junção dos DataFrames `df_sexo, df_sexo_tipo` para criar um novo DataFrame chamado `df_juncao` contendo as contagens por sexo e também por sexo/tipo.

# %%
# Resposta:

df_juncao = pd.merge(df_sexo, df_sexo_tipo)

df_juncao
# Out:
#    SEXO  CONTAGEM         TIPO  TOTAL
# 0     F      3613     DENÚNCIA     31
# 1     F      3613       ELOGIO     65
# 2     F      3613   INFORMAÇÃO     25
# 3     F      3613   RECADASTRO     79
# 4     F      3613   RECLAMAÇÃO    555
# 5     F      3613  SOLICITAÇÃO   2851
# 6     F      3613     SUGESTÃO      7
# 7     M      3400     DENÚNCIA     13
# 8     M      3400       ELOGIO     34
# 9     M      3400   INFORMAÇÃO     11
# 10    M      3400   RECADASTRO     91
# 11    M      3400   RECLAMAÇÃO    282
# 12    M      3400  SOLICITAÇÃO   2961
# 13    M      3400     SUGESTÃO      8

# %% [markdown]
# Crie uma nova coluna no DataFrame `df_juncao` chamada `proporcao` contendo a porcentagem de homens e mulheres que fizeram cada tipo de reclamação. Responda: qual sexo faz mais elogios? Qual faz mais solicitações? Qual faz mais reclamações?

# %%
df_juncao['PROPORCAO'] = (df_juncao['TOTAL'] / df_juncao['TOTAL'].sum()) * 100

df_juncao
# Out:
#    SEXO  CONTAGEM         TIPO  TOTAL  PROPORCAO
# 0     F      3613     DENÚNCIA     31   0.442036
# 1     F      3613       ELOGIO     65   0.926850
# 2     F      3613   INFORMAÇÃO     25   0.356481
# 3     F      3613   RECADASTRO     79   1.126479
# 4     F      3613   RECLAMAÇÃO    555   7.913874
# 5     F      3613  SOLICITAÇÃO   2851  40.653073
# 6     F      3613     SUGESTÃO      7   0.099815
# 7     M      3400     DENÚNCIA     13   0.185370
# 8     M      3400       ELOGIO     34   0.484814
# 9     M      3400   INFORMAÇÃO     11   0.156852
# 10    M      3400   RECADASTRO     91   1.297590
# 11    M      3400   RECLAMAÇÃO    282   4.021104
# 12    M      3400  SOLICITAÇÃO   2961  42.221588
# 13    M      3400     SUGESTÃO      8   0.114074

# %%
#Resposta
#Qual sexo faz mais elogios?

m = int(df_juncao[(df_juncao['TIPO'] == 'ELOGIO') & (df_juncao['SEXO'] == 'M')]['TOTAL'])
f = int(df_juncao[(df_juncao['TIPO'] == 'ELOGIO') & (df_juncao['SEXO'] == 'F')]['TOTAL'])

if m > f:
    print ('Homens fazem mais elogios do que as mulheres!')
elif m == f:
    print ('Ambos fazem a mesma quantidade de elogios!')
else:
    print ('Mulheres fazem mais elogios do que os homens!')
# Out:
# Mulheres fazem mais elogios do que os homens!

# %%
#Resposta
#Qual faz mais solicitações?

m = int(df_juncao[(df_juncao['TIPO'] == 'SOLICITAÇÃO') & (df_juncao['SEXO'] == 'M')]['TOTAL'])
f = int(df_juncao[(df_juncao['TIPO'] == 'SOLICITAÇÃO') & (df_juncao['SEXO'] == 'F')]['TOTAL'])

if m > f:
    print ('Homens fazem mais solicitações do que as mulheres!')
elif m == f:
    print ('Ambos fazem a mesma quantidade de solicitações!')
else:
    print ('Mulheres fazem mais solicitações do que os homens!')
# Out:
# Homens fazem mais solicitações do que as mulheres!

# %%
#Resposta
#Qual faz mais reclamações?

m = int(df_juncao[(df_juncao['TIPO'] == 'RECLAMAÇÃO') & (df_juncao['SEXO'] == 'M')]['TOTAL'])
f = int(df_juncao[(df_juncao['TIPO'] == 'RECLAMAÇÃO') & (df_juncao['SEXO'] == 'F')]['TOTAL'])

if m > f:
    print ('Homens fazem mais reclamações do que as mulheres!')
elif m == f:
    print ('Ambos fazem a mesma quantidade de reclamações!')
else:
    print ('Mulheres fazem mais reclamações do que os homens!')
# Out:
# Mulheres fazem mais reclamações do que os homens!
