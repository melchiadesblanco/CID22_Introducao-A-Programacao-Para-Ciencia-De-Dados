# %% [markdown]
# # Introdução a Pandas
#
# Pandas é uma biblioteca para a manipulação de DataFrames. DataFrames são dados estruturados em formato de planilha. Quem está familiarizado com o Excel pode perceber que o Pandas faz coisas parecidas, como criação de novas colunas usando fórmulas, ordenação de valores, cálculo de estatísticas, plotagem de gráficos etc. A vantagem do Pandas é poder fazer isto tudo de uma forma programável, que se adequa até mesmo a grandes quantidades de dados.
#
# Para usar o Pandas, o primeiro passo é importar a biblioteca. Aqui usamos o "apelido" *pd* para nos referenciarmos à biblioteca nas próximas células. Execute todas as células de código do tutorial para ver o resultado.

# %%
#importing libraries
import pandas as pd

#%matplotlib inline

# %% [markdown]
# ## Lendo dados de um arquivo
#
# Muitos dados são gravados em arquivos CSV (Comma Separated Values, ou Valores Separados por Vírgula). É muito fácil importar dados em CSV usando o Pandas, como mostra a célula abaixo. Estes dados também poderiam vir de uma planilha do Excel ou de um banco de dados, dependendo do caso.
#
# Nos comandos abaixo, o método *read_csv* lê os dados do arquivo *aluguel.csv* que se encontra na pasta *data*. Os dados são atribuídos para o DataFrame que chamamos de df (mas poderíamos usar qualquer outro nome). Para exibir o conteúdo do DataFrame, basta escrever o nome na última linha da célula.
#
# O DataFrame carregado contém dados de apartamentos para alugar na cidade de Curitiba.

# %%
# lê o arquivo CSV
df = pd.read_csv('../data/aluguel.csv')

# mostra o conteúdo do DataFrame
df
# Out:
#     codigo                        endereco  quartos  suite  area  vaga  \
# 0       34    Rua Desembargador Westphalen        2      0    90     0
# 1      167               Rua Jose Loureiro        2      0    64     0
# 2     6784               Rua Jose Loureiro        2      0    81     0
# 3       82              Rua Lourenço Pinto        2      0    50     0
# 4     2970              Rua Lourenço Pinto        2      0    63     0
# 5    34197           Alameda Doutor Muricy        2      0    80     1
# 6     5072           Alameda Doutor Muricy        2      0    84     0
# 7      469    Rua Desembargador Westphalen        1      0    30     0
# 8       24    Rua Desembargador Westphalen        1      0    60     1
# 9       74  Avenida Visconde de Guarapuava        2      1   132     1
# 10    9850  Avenida Visconde de Guarapuava        1      0    64     1
# 11   82343        Avenida Sete de Setembro        1      0    45     0
# 12   20802        Avenida Sete de Setembro        1      0    47     0
# 13     568                Rua Alferes Poli        1      0    43     0
# 14  294579            Avenida Silva Jardim        1      0    36     0
# 15   59375            Avenida Silva Jardim        1      0    33     0
# 16      80    Rua Desembargador Westphalen        1      0    80     1
# 17   66490    Rua Desembargador Westphalen        1      0    80     1
# 18    2381                 Rua Rockefeller        2      0    54     0
# 19   44803                 Rua Rockefeller        2      0    77     1
#
#     aluguel  condominio      data
# 0       900         371  11/10/17
# 1       650         428  15/07/17
# 2      1100         400  23/08/17
# 3      1350         300  19/09/17
# 4      1300         300  05/08/17
# 5       900         410  23/10/17
# 6      1100         382  02/09/17
# 7       550         210  03/07/17
# 8       800         120  30/09/17
# 9      1800         520  12/10/17
# 10      600         326  15/07/17
# 11      750         420  11/10/17
# 12      600         405  27/07/17
# 13      600         330  12/08/17
# 14      550         350  01/10/17
# 15      560         305  11/09/17
# 16      900         350  12/08/17
# 17     1100         350  29/08/17
# 18      900         240  19/09/17
# 19      950         200  19/07/17

# %% [markdown]
# Para saber o tamanho do DataFrame, podemos usar a função `len()`:

# %%
print("Tamanho do DataFrame: ", len(df))
df.shape
# Out:
# Tamanho do DataFrame:  20
# (20, 9)

# %% [markdown]
# ## Manipulando o DataFrame
#
# Podemos manipular o DataFrame de diversas formas. É possível criar novos DataFrames com subconjuntos de colunas do DataFrame original. Abaixo um DataFrame chamado df_small é criado com o conteúdo das colunas aluguel e condominio.

# %%
df_small = df[['aluguel', 'condominio']]

df_small
# Out:
#     aluguel  condominio
# 0       900         371
# 1       650         428
# 2      1100         400
# 3      1350         300
# 4      1300         300
# 5       900         410
# 6      1100         382
# 7       550         210
# 8       800         120
# 9      1800         520
# 10      600         326
# 11      750         420
# 12      600         405
# 13      600         330
# 14      550         350
# 15      560         305
# 16      900         350
# 17     1100         350
# 18      900         240
# 19      950         200

# %% [markdown]
# Também é possível selecionar subconjuntos das linhas do DataFrame. Abaixo selecionamos apenas as linhas representando apartamentos de área maior que $50m^2$.

# %%
df[df.area > 50]
# Out:
#     codigo                        endereco  quartos  suite  area  vaga  \
# 0       34    Rua Desembargador Westphalen        2      0    90     0
# 1      167               Rua Jose Loureiro        2      0    64     0
# 2     6784               Rua Jose Loureiro        2      0    81     0
# 4     2970              Rua Lourenço Pinto        2      0    63     0
# 5    34197           Alameda Doutor Muricy        2      0    80     1
# 6     5072           Alameda Doutor Muricy        2      0    84     0
# 8       24    Rua Desembargador Westphalen        1      0    60     1
# 9       74  Avenida Visconde de Guarapuava        2      1   132     1
# 10    9850  Avenida Visconde de Guarapuava        1      0    64     1
# 16      80    Rua Desembargador Westphalen        1      0    80     1
# 17   66490    Rua Desembargador Westphalen        1      0    80     1
# 18    2381                 Rua Rockefeller        2      0    54     0
# 19   44803                 Rua Rockefeller        2      0    77     1
#
#     aluguel  condominio      data
# 0       900         371  11/10/17
# 1       650         428  15/07/17
# 2      1100         400  23/08/17
# 4      1300         300  05/08/17
# 5       900         410  23/10/17
# 6      1100         382  02/09/17
# 8       800         120  30/09/17
# 9      1800         520  12/10/17
# 10      600         326  15/07/17
# 16      900         350  12/08/17
# 17     1100         350  29/08/17
# 18      900         240  19/09/17
# 19      950         200  19/07/17

# %% [markdown]
# Podemos também transpor (rotacionar) um DataFrame:

# %%
df.T
# Out:
#                                       0                  1   \
# codigo                                34                167
# endereco    Rua Desembargador Westphalen  Rua Jose Loureiro
# quartos                                2                  2
# suite                                  0                  0
# area                                  90                 64
# vaga                                   0                  0
# aluguel                              900                650
# condominio                           371                428
# data                            11/10/17           15/07/17
#
#                            2                   3                   4   \
# codigo                   6784                  82                2970
# endereco    Rua Jose Loureiro  Rua Lourenço Pinto  Rua Lourenço Pinto
# quartos                     2                   2                   2
# suite                       0                   0                   0
# area                       81                  50                  63
# vaga                        0                   0                   0
# aluguel                  1100                1350                1300
# condominio                400                 300                 300
# data                 23/08/17            19/09/17            05/08/17
#
#                                5                      6   \
# codigo                      34197                   5072
# endereco    Alameda Doutor Muricy  Alameda Doutor Muricy
# quartos                         2                      2
# suite                           0                      0
# area                           80                     84
# vaga                            1                      0
# aluguel                       900                   1100
# condominio                    410                    382
# data                     23/10/17               02/09/17
#
#                                       7                             8   \
# codigo                               469                            24
# endereco    Rua Desembargador Westphalen  Rua Desembargador Westphalen
# quartos                                1                             1
# suite                                  0                             0
# area                                  30                            60
# vaga                                   0                             1
# aluguel                              550                           800
# condominio                           210                           120
# data                            03/07/17                      30/09/17
#
#                                         9                               10  \
# codigo                                  74                            9850
# endereco    Avenida Visconde de Guarapuava  Avenida Visconde de Guarapuava
# quartos                                  2                               1
# suite                                    1                               0
# area                                   132                              64
# vaga                                     1                               1
# aluguel                               1800                             600
# condominio                             520                             326
# data                              12/10/17                        15/07/17
#
#                                   11                        12  \
# codigo                         82343                     20802
# endereco    Avenida Sete de Setembro  Avenida Sete de Setembro
# quartos                            1                         1
# suite                              0                         0
# area                              45                        47
# vaga                               0                         0
# aluguel                          750                       600
# condominio                       420                       405
# data                        11/10/17                  27/07/17
#
#                           13                    14                    15  \
# codigo                   568                294579                 59375
# endereco    Rua Alferes Poli  Avenida Silva Jardim  Avenida Silva Jardim
# quartos                    1                     1                     1
# suite                      0                     0                     0
# area                      43                    36                    33
# vaga                       0                     0                     0
# aluguel                  600                   550                   560
# condominio               330                   350                   305
# data                12/08/17              01/10/17              11/09/17
#
#                                       16                            17  \
# codigo                                80                         66490
# endereco    Rua Desembargador Westphalen  Rua Desembargador Westphalen
# quartos                                1                             1
# suite                                  0                             0
# area                                  80                            80
# vaga                                   1                             1
# aluguel                              900                          1100
# condominio                           350                           350
# data                            12/08/17                      29/08/17
#
#                          18               19
# codigo                 2381            44803
# endereco    Rua Rockefeller  Rua Rockefeller
# quartos                   2                2
# suite                     0                0
# area                     54               77
# vaga                      0                1
# aluguel                 900              950
# condominio              240              200
# data               19/09/17         19/07/17

# %% [markdown]
# Perceba que o comando acima não alterou o DataFrame original, como pode ser visto abaixo. Ele apenas retornou um novo DataFrame. Para alterar um DataFrame, em geral, você precisa atribuir o resultado do comando à variável original. Por exemplo, usando df = df.T

# %%
df
# Out:
#     codigo                        endereco  quartos  suite  area  vaga  \
# 0       34    Rua Desembargador Westphalen        2      0    90     0
# 1      167               Rua Jose Loureiro        2      0    64     0
# 2     6784               Rua Jose Loureiro        2      0    81     0
# 3       82              Rua Lourenço Pinto        2      0    50     0
# 4     2970              Rua Lourenço Pinto        2      0    63     0
# 5    34197           Alameda Doutor Muricy        2      0    80     1
# 6     5072           Alameda Doutor Muricy        2      0    84     0
# 7      469    Rua Desembargador Westphalen        1      0    30     0
# 8       24    Rua Desembargador Westphalen        1      0    60     1
# 9       74  Avenida Visconde de Guarapuava        2      1   132     1
# 10    9850  Avenida Visconde de Guarapuava        1      0    64     1
# 11   82343        Avenida Sete de Setembro        1      0    45     0
# 12   20802        Avenida Sete de Setembro        1      0    47     0
# 13     568                Rua Alferes Poli        1      0    43     0
# 14  294579            Avenida Silva Jardim        1      0    36     0
# 15   59375            Avenida Silva Jardim        1      0    33     0
# 16      80    Rua Desembargador Westphalen        1      0    80     1
# 17   66490    Rua Desembargador Westphalen        1      0    80     1
# 18    2381                 Rua Rockefeller        2      0    54     0
# 19   44803                 Rua Rockefeller        2      0    77     1
#
#     aluguel  condominio      data
# 0       900         371  11/10/17
# 1       650         428  15/07/17
# 2      1100         400  23/08/17
# 3      1350         300  19/09/17
# 4      1300         300  05/08/17
# 5       900         410  23/10/17
# 6      1100         382  02/09/17
# 7       550         210  03/07/17
# 8       800         120  30/09/17
# 9      1800         520  12/10/17
# 10      600         326  15/07/17
# 11      750         420  11/10/17
# 12      600         405  27/07/17
# 13      600         330  12/08/17
# 14      550         350  01/10/17
# 15      560         305  11/09/17
# 16      900         350  12/08/17
# 17     1100         350  29/08/17
# 18      900         240  19/09/17
# 19      950         200  19/07/17

# %% [markdown]
# É possível criar novas colunas a partir de outras colunas do DataFrame. Abaixo criamos uma coluna chamada *total* contendo o valor do aluguel somado ao condomínio.

# %%
df['total'] = df['aluguel'] + df['condominio']

df
# Out:
#     codigo                        endereco  quartos  suite  area  vaga  \
# 0       34    Rua Desembargador Westphalen        2      0    90     0
# 1      167               Rua Jose Loureiro        2      0    64     0
# 2     6784               Rua Jose Loureiro        2      0    81     0
# 3       82              Rua Lourenço Pinto        2      0    50     0
# 4     2970              Rua Lourenço Pinto        2      0    63     0
# 5    34197           Alameda Doutor Muricy        2      0    80     1
# 6     5072           Alameda Doutor Muricy        2      0    84     0
# 7      469    Rua Desembargador Westphalen        1      0    30     0
# 8       24    Rua Desembargador Westphalen        1      0    60     1
# 9       74  Avenida Visconde de Guarapuava        2      1   132     1
# 10    9850  Avenida Visconde de Guarapuava        1      0    64     1
# 11   82343        Avenida Sete de Setembro        1      0    45     0
# 12   20802        Avenida Sete de Setembro        1      0    47     0
# 13     568                Rua Alferes Poli        1      0    43     0
# 14  294579            Avenida Silva Jardim        1      0    36     0
# 15   59375            Avenida Silva Jardim        1      0    33     0
# 16      80    Rua Desembargador Westphalen        1      0    80     1
# 17   66490    Rua Desembargador Westphalen        1      0    80     1
# 18    2381                 Rua Rockefeller        2      0    54     0
# 19   44803                 Rua Rockefeller        2      0    77     1
#
#     aluguel  condominio      data  total
# 0       900         371  11/10/17   1271
# 1       650         428  15/07/17   1078
# 2      1100         400  23/08/17   1500
# 3      1350         300  19/09/17   1650
# 4      1300         300  05/08/17   1600
# 5       900         410  23/10/17   1310
# 6      1100         382  02/09/17   1482
# 7       550         210  03/07/17    760
# 8       800         120  30/09/17    920
# 9      1800         520  12/10/17   2320
# 10      600         326  15/07/17    926
# 11      750         420  11/10/17   1170
# 12      600         405  27/07/17   1005
# 13      600         330  12/08/17    930
# 14      550         350  01/10/17    900
# 15      560         305  11/09/17    865
# 16      900         350  12/08/17   1250
# 17     1100         350  29/08/17   1450
# 18      900         240  19/09/17   1140
# 19      950         200  19/07/17   1150

# %% [markdown]
# ### Exercício
#
# Suponha que o seu orçamento para alugar um apartamento é de R$ 900. Crie uma nova coluna com o nome "diferença" que contenha o valor que irá sobrar/faltar do seu orçamento de acordo com o valor total do apartamento.

# %%
df['diferenca'] = df['total'] - 900

df
# Out:
#     codigo                        endereco  quartos  suite  area  vaga  \
# 0       34    Rua Desembargador Westphalen        2      0    90     0
# 1      167               Rua Jose Loureiro        2      0    64     0
# 2     6784               Rua Jose Loureiro        2      0    81     0
# 3       82              Rua Lourenço Pinto        2      0    50     0
# 4     2970              Rua Lourenço Pinto        2      0    63     0
# 5    34197           Alameda Doutor Muricy        2      0    80     1
# 6     5072           Alameda Doutor Muricy        2      0    84     0
# 7      469    Rua Desembargador Westphalen        1      0    30     0
# 8       24    Rua Desembargador Westphalen        1      0    60     1
# 9       74  Avenida Visconde de Guarapuava        2      1   132     1
# 10    9850  Avenida Visconde de Guarapuava        1      0    64     1
# 11   82343        Avenida Sete de Setembro        1      0    45     0
# 12   20802        Avenida Sete de Setembro        1      0    47     0
# 13     568                Rua Alferes Poli        1      0    43     0
# 14  294579            Avenida Silva Jardim        1      0    36     0
# 15   59375            Avenida Silva Jardim        1      0    33     0
# 16      80    Rua Desembargador Westphalen        1      0    80     1
# 17   66490    Rua Desembargador Westphalen        1      0    80     1
# 18    2381                 Rua Rockefeller        2      0    54     0
# 19   44803                 Rua Rockefeller        2      0    77     1
#
#     aluguel  condominio      data  total  diferenca
# 0       900         371  11/10/17   1271        371
# 1       650         428  15/07/17   1078        178
# 2      1100         400  23/08/17   1500        600
# 3      1350         300  19/09/17   1650        750
# 4      1300         300  05/08/17   1600        700
# 5       900         410  23/10/17   1310        410
# 6      1100         382  02/09/17   1482        582
# 7       550         210  03/07/17    760       -140
# 8       800         120  30/09/17    920         20
# 9      1800         520  12/10/17   2320       1420
# 10      600         326  15/07/17    926         26
# 11      750         420  11/10/17   1170        270
# 12      600         405  27/07/17   1005        105
# 13      600         330  12/08/17    930         30
# 14      550         350  01/10/17    900          0
# 15      560         305  11/09/17    865        -35
# 16      900         350  12/08/17   1250        350
# 17     1100         350  29/08/17   1450        550
# 18      900         240  19/09/17   1140        240
# 19      950         200  19/07/17   1150        250

# %% [markdown]
# ## Analisando dados do DataFrame
#
# Os DataFrames possuem um método chamado *describe* que exibe estatísticas sobre as colunas do DataFrame. Por exemplo, como pode ser visto abaixo, o valor máximo para o condomínio é 520, enquanto a média é 335.85.

# %%
df.describe()
# Out:
#               codigo    quartos      suite        area      vaga      aluguel  \
# count      20.000000  20.000000  20.000000   20.000000  20.00000    20.000000
# mean    31557.200000   1.500000   0.050000   64.650000   0.35000   898.000000
# std     67034.809578   0.512989   0.223607   24.303509   0.48936   326.102987
# min        24.000000   1.000000   0.000000   30.000000   0.00000   550.000000
# 25%       145.750000   1.000000   0.000000   46.500000   0.00000   600.000000
# 50%      4021.000000   1.500000   0.000000   63.500000   0.00000   900.000000
# 75%     36848.500000   2.000000   0.000000   80.000000   1.00000  1100.000000
# max    294579.000000   2.000000   1.000000  132.000000   1.00000  1800.000000
#
#        condominio        total    diferenca
# count    20.00000    20.000000    20.000000
# mean    335.85000  1233.850000   333.850000
# std      92.21558   364.746383   364.746383
# min     120.00000   760.000000  -140.000000
# 25%     300.00000   929.000000    29.000000
# 50%     350.00000  1160.000000   260.000000
# 75%     401.25000  1458.000000   558.000000
# max     520.00000  2320.000000  1420.000000

# %% [markdown]
# DataFrames também suportam a plotagem de gráficos. Por exemplo, abaixo temos Box Plots representando a distribuição dos valores de aluguel e condomínio. Mais detalhes sobre plotagem de gráficos serão fornecidos em um outro momento.

# %%
df_small.plot.box()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %% [markdown]
# É possível calcular a média de uma coluna:

# %%
df['aluguel'].mean()
# Out:
# 898.0

# %% [markdown]
# E várias outras estatísticas:

# %%
print(df['aluguel'].mean(), df['aluguel'].min(), df['aluguel'].max())
# Out:
# 898.0 550 1800

# %% [markdown]
# Para ordenar um DataFrame baseado em valores de uma coluna, use:

# %%
df.sort_values('total')
# Out:
#     codigo                        endereco  quartos  suite  area  vaga  \
# 7      469    Rua Desembargador Westphalen        1      0    30     0
# 15   59375            Avenida Silva Jardim        1      0    33     0
# 14  294579            Avenida Silva Jardim        1      0    36     0
# 8       24    Rua Desembargador Westphalen        1      0    60     1
# 10    9850  Avenida Visconde de Guarapuava        1      0    64     1
# 13     568                Rua Alferes Poli        1      0    43     0
# 12   20802        Avenida Sete de Setembro        1      0    47     0
# 1      167               Rua Jose Loureiro        2      0    64     0
# 18    2381                 Rua Rockefeller        2      0    54     0
# 19   44803                 Rua Rockefeller        2      0    77     1
# 11   82343        Avenida Sete de Setembro        1      0    45     0
# 16      80    Rua Desembargador Westphalen        1      0    80     1
# 0       34    Rua Desembargador Westphalen        2      0    90     0
# 5    34197           Alameda Doutor Muricy        2      0    80     1
# 17   66490    Rua Desembargador Westphalen        1      0    80     1
# 6     5072           Alameda Doutor Muricy        2      0    84     0
# 2     6784               Rua Jose Loureiro        2      0    81     0
# 4     2970              Rua Lourenço Pinto        2      0    63     0
# 3       82              Rua Lourenço Pinto        2      0    50     0
# 9       74  Avenida Visconde de Guarapuava        2      1   132     1
#
#     aluguel  condominio      data  total  diferenca
# 7       550         210  03/07/17    760       -140
# 15      560         305  11/09/17    865        -35
# 14      550         350  01/10/17    900          0
# 8       800         120  30/09/17    920         20
# 10      600         326  15/07/17    926         26
# 13      600         330  12/08/17    930         30
# 12      600         405  27/07/17   1005        105
# 1       650         428  15/07/17   1078        178
# 18      900         240  19/09/17   1140        240
# 19      950         200  19/07/17   1150        250
# 11      750         420  11/10/17   1170        270
# 16      900         350  12/08/17   1250        350
# 0       900         371  11/10/17   1271        371
# 5       900         410  23/10/17   1310        410
# 17     1100         350  29/08/17   1450        550
# 6      1100         382  02/09/17   1482        582
# 2      1100         400  23/08/17   1500        600
# 4      1300         300  05/08/17   1600        700
# 3      1350         300  19/09/17   1650        750
# 9      1800         520  12/10/17   2320       1420
